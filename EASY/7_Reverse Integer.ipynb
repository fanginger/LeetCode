# %% [markdown]
# ## 7. Reverse Integer
#
# Given a signed 32-bit integer x, return x with its digits reversed. If reversing x causes the value to go outside the signed 32-bit integer range [-231, 231 - 1], then return 0.

# %%
class Solution:
    def reverse(self, x: int) -> int:
        long = len(str(x))
        temp = []
        s = ''
        minus = False 
        for y in str(x):
            if y == '-':
                minus = True
            else:
                temp.insert(0,y)
        print(temp)
        if minus == True:
            temp.insert(0,'-')
        for y in temp:
            s += y
        if int(s) > (2**31) or int(s) < ((-2)**31):
            s  = 0
        return int(s)

# %%
sol = Solution()
test = sol.reverse(121)
# Out:
# ['1', '2', '1']

# %%
test
# Out:
# 121

# %%
class Solution:
    def reverse(self, x: int) -> int:
        ans=int(str(abs(x))[::-1])
        if (ans>pow(2,31)-1 or ans<-pow(2,31)):
            return 0
        return ans if x>=0 else -ans

# %% [markdown]
# String 也可以以 list 方式做擷取

# %%
# Out:
# False
